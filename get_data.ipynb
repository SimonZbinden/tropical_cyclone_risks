# %%
import pandas as pd

# %%
df = pd.read_excel("data1.xlsx", index_col="Ecoregion ID")

# %%
# Assuming your DataFrame is named 'df'
filtered_df = df[df['Ecoregion'].str.contains('philip', case=False, na=False)]

print(filtered_df)
# Out:
# Empty DataFrame
# Columns: [Ecoregion, Biome, Vulnerability (L), Return Period (L) [years], Vulnerability (M), Return Period (M) [years], Vulnerability (H), Return Period (H) [years]]
# Index: []

# %%
df
# Out:
#                                           Ecoregion                 Biome  \
# Ecoregion ID
# 8                    Alaska Peninsula montane taiga  Boreal Forests/Taiga
# 126                 Central Canadian Shield forests  Boreal Forests/Taiga
# 167                                Cook Inlet taiga  Boreal Forests/Taiga
# 209                             East Siberian taiga  Boreal Forests/Taiga
# 217                   Eastern Canadian Shield taiga  Boreal Forests/Taiga
# ...                                             ...                   ...
# 731                         Torngat Mountain tundra                Tundra
# 733               Trans-Baikal Bald Mountain tundra                Tundra
# 661            Southern Indian Ocean Islands tundra                Tundra
# 30            Antipodes Subantarctic Islands tundra                Tundra
# 14                          Aleutian Islands tundra                Tundra
#
# ...
